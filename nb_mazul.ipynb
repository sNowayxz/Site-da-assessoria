# %%
import requests

url_login = "https://gateway.unicesumar.edu.br/mundoazul-api-controle-acesso/oauth/token"

payload = {
        "username":"rossana.paz",
        "password": "#Euvouvencer1",
        "grant_type":"password"
    }

headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7",
    "Authorization": "Basic TVVORE9fQVpVTDplbXRlcnJhZGVzYWNpcXVlbXRlbTFvbGhvZXJlaUB1bmljZXN1bWFyLmVkdS5icg==",
    "Content-Type": "application/x-www-form-urlencoded",
    "Origin": "https://mundoazul.unicesumar.edu.br",
    "Referer": "https://mundoazul.unicesumar.edu.br/",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36",
}


resp = requests.post(url_login, data=payload, headers=headers, timeout=30)
print(resp.status_code)
print(resp.text)
# Out:
# 200
# {"access_token":"ca1e5b37-8526-44ba-b2e0-5be5fd1975ce","token_type":"bearer","refresh_token":"bf259c26-50bc-45eb-8d05-fbd6ccb2b8aa","expires_in":34862,"scope":"open read write trust"}

# %%
data = resp.json()
token = data['access_token']

headers["Authorization"] = f"Bearer {token}"

# %%
headers = {
    "Authorization": f"Bearer {token}",
    "Accept": "application/json",
    "Content-Type": "application/json",
    # estes dois só se o backend validar origem (geralmente não precisa fora do browser)
    "Origin": "https://mundoazul.unicesumar.edu.br",
    "Referer": "https://mundoazul.unicesumar.edu.br/",
    # opcional: imitar user-agent do navegador
    "User-Agent": "Mozilla/5.0",
}

url_cadastro = "https://gateway.unicesumar.edu.br/mundoazul-api-studeo/api/liberacao-terminal"

payload_cadastro = {"idPolo":"056","code":"73774352-3965-472f-b6ec-6411d98f14e3"}


resp_cadastro = requests.post(url_cadastro, headers=headers, json=payload_cadastro, timeout=30)

resp_cadastro.status_code
# Out:
# 404

# %%
# 2448

# %%
from system.crypto import recodification


p = "H9d;{<FNrT5oR85:ki+9WKAqd9CP>[YW.h_+lF;b8gm! z)tAiq,rixjHTV"

recodification(p)
# Out:
# 'd3371gw@'

# %%
l = ",MLYa%^ FhDoISa^Q]aUw$Y33+COdGF[)J.(h50zWO [,aax~%rpp#XDNGmccEC477u-#WvG8v.ho+(gBsF=6~S"

recodification(l)
# Out:
# 'silvamariajoana244@gmail.com'

# %%
4000%2000
# Out:
# 0
