# %%
import json
from bs4 import BeautifulSoup as BS

import requests as rq

questao = """
A quarta Revolução Industrial é o marco em que vivemos atualmente, presenciando a integração digital em todos os níveis empresariais, permitindo um controle e observação de todos os pontos de uma produção. Entretanto, esse período é totalmente capaz de se alterar, criando novas condições e alcançando grupos e segmentos que antes eram considerados totalmente impossíveis de absorver tecnologia. Contudo, há uma grande preocupação em manter o nível elevado que essa revolução exige, o que demanda muito conhecimento na área e resiliência para garantir seu correto funcionamento.
"""

data = {"query":{"text":questao},"context":{"scenario":"","supportedTypes":["question"],"requestId":""},"pagination":{"cursor":None,"limit":3}}

headers = {
    "Accept": "/",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7",
    "Connection": "keep-alive",
    "Content-Length": "255",
    "Content-Type": "text/plain;charset=UTF-8",
    "Host": "srv-unified-search.external.search-systems-production.z-dn.net",
    "Origin": "https://brainly.com.br",
    "Referer": "https://brainly.com.br/",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "cross-site",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
    "sec-ch-ua": "\"Not.A/Brand\";v=\"8\", \"Chromium\";v=\"114\", \"Google Chrome\";v=\"114\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "x-api-key": "22df2c14-f58b-4603-abf2-788ba76862a0" 
}


url = "https://srv-unified-search.external.search-systems-production.z-dn.net/api/v1/pt/search"

# %%
r = rq.post(url = url, headers = headers , data = json.dumps(data))

result = r.json()

# %%
print(result)
# Out:
# {'metadata': {'answerBot': {'missingReason': 'other_top_hit'}, 'queryText': '\nA quarta Revolução Industrial é o marco em que vivemos atualmente, presenciando a integração digital em todos os níveis empresariais, permitindo um controle e observação de todos os pontos de uma produção. Entretanto, esse período é totalmente capaz de se alterar, criando novas condições e alcançando grupos e segmentos que antes eram considerados totalmente impossíveis de absorver tecnologia. Contudo, há uma grande preocupação em manter o nível elevado que essa revolução exige, o que demanda muito conhecimento na área e resiliência para garantir seu correto funcionamento.\n', 'requestId': '4844964aa0d42e7093b398a7444d9d92', 'requestedTypes': ['question'], 'usedScenario': 'math-routing-search-gdai'}, 'pagination': {'cursor': 'eyJxYSI6Mn0', 'hasNextPage': True}, 'results': [{'question': {'answer': {'aiAssisted': False, 'attachments': None, 'author': {'avatarUrl': '', 'category': 600, 'id': 67986433, 'nick': 
# ...

# %%
id = result["results"][0]["question"]["id"]

verified = result["results"][0]["question"]["answer"]["verified"]

resposta = result["results"][2]["question"]["answer"]["content"]


likes =  result["results"][0]["question"]["answer"]["thanksCount"] , result["results"][1]["question"]["answer"]["thanksCount"] , result["results"][2]["question"]["answer"]["thanksCount"]
print(likes)
# Out:
# (4, 0, 36)

# %%
soup = BS(resposta, 'html.parser')

print(soup)
# Out:
# <p><strong>Resposta:</strong></p><p><strong>Alternativa 5:</strong></p><p><strong>I, II, III e IV.</strong></p><p></p><p><strong>Explicação:</strong></p><p><strong>I. O período apresenta situações altamente voláteis.</strong></p><p><strong>Voláteis significa mudável, e entendo que estamos vivendo um período de mudança.</strong></p><p><strong>II. A tecnologia se mostra como protagonista das mudanças.</strong></p><p><strong>Sim a tecnologia é sem duvidas a protagonista</strong></p><p><strong>III. A integração acontece entre todos os setores e produções.</strong></p><p><strong>Também entendo que deve haver a integração de todos os setores</strong></p><p><strong>IV. O movimento exige domínio de conhecimento digital e macrovisão dos negócios.</strong></p><p><strong>Sem duvidas esta está correta.</strong></p><p></p>

# %%
print(dir("ass"))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
tags = []
trechos = soup.find_all()
print(trechos)

# %%
from system.system import tratar_resposta

resposta_tratada = tratar_resposta(resposta)

# %%
print(resposta_tratada)

# %%
import os
import requests as rq
from bs4 import BeautifulSoup as BS
 

from function import scrapped_id_resposta, t, tratar_resposta
from function_bd import abre_json, integridade_bd, save_json
from function_chrome import login_papiron
from function_criptografia import recodification, recupera_dados

keys_atividade =  ["STATUS_ATIVIDADE","ID_URL","DT_INICIO", "DT_FIM"]
modulo = "202353"
path_user = os.getcwd()+'\\BD\\atividades\\user_data.json'
user = abre_json(path_file= path_user)
headers = login_papiron( recodification(user["usuario"]), recodification(user["password"]), url_base ="https://www.papiron.com.br/")

# %%
id_url = "JNJYV5B5BTVSsdZFsfF799"
url = "https://www.papiron.com.br/atividades/"+id_url
r = rq.get(url = url,  headers = headers , allow_redirects=True)
soup = BS(r.content, "html.parser")
print(soup)

# %%
print(type(soup) , dir(soup) , soup.contents)

# %%
tag = soup.find("div",{"id":id_url})
print(tag)

# %%
st = """O Planejamento e Controle da Produção (PCP) é uma área da gestão de operações que lida com o planejamento, programação e controle de todas as atividades relacionadas à produção de bens ou serviços em uma organização."""

print(len(st))
