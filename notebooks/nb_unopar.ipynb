# %%
import requests as rq
from bs4 import BeautifulSoup as BS

URL= "https://portifolioos-prontos.com/index.php/product/projeto-de-extensao-ii-comercio-exterior/"

r = rq.get(URL)

soup = BS(r.content, "html.parser")

# %%
post = soup.find('div',{'class':"woocommerce-Tabs-panel woocommerce-Tabs-panel--description panel entry-content wc-tab"})
linhas = post.find_all('td')
linhas
# Out:
# [<td colspan="11">CURSO:</td>,
#  <td colspan="11"><strong>CST EM COMÉRCIO EXTERIOR</strong></td>,
#  <td colspan="11">COMPONENTE CURRICULAR:</td>,
#  <td colspan="11"><strong>PROJETO DE EXTENSÃO II – COMÉRCIO EXTERIOR</strong></td>,
#  <td colspan="11">PROGRAMA DE EXTENSÃO:</td>,
#  <td colspan="11"><strong>PROGRAMA DE CONTEXTO À COMUNIDADE.</strong></td>,
#  <td colspan="11"><strong> </strong></td>,
#  <td colspan="11">FINALIDADE E MOTIVAÇÃO:</td>,
# ...
